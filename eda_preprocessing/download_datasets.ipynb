# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("austinreese/craigslist-carstrucks-data")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/austinreese/craigslist-carstrucks-data?dataset_version_number=10...
# 100%|██████████| 262M/262M [00:24<00:00, 11.3MB/s]
# Extracting files...
# Path to dataset files: /home/cavins/.cache/kagglehub/datasets/austinreese/craigslist-carstrucks-data/versions/10

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ananaymital/us-used-cars-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ananaymital/us-used-cars-dataset?dataset_version_number=1...
# 100%|██████████| 2.13G/2.13G [03:21<00:00, 11.3MB/s]
# Extracting files...
# Path to dataset files: /home/cavins/.cache/kagglehub/datasets/ananaymital/us-used-cars-dataset/versions/1
